# %% [markdown]
# ## Las matematicas tras la Regresion Logistica
#
#
# #### Las tablas de contingencia

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Asus\Desktop\Datasets\datasets\gender-purchase\Gender Purchase.csv")

# %%
df.head()
# Out:
#    Gender Purchase
# 0  Female      Yes
# 1  Female      Yes
# 2  Female       No
# 3    Male       No
# 4    Male      Yes

# %%
df.shape
# Out:
# (511, 2)

# %%
contingency_table = pd.crosstab(df["Gender"],df["Purchase"])

# %%
contingency_table
# Out:
# Purchase   No  Yes
# Gender
# Female    106  159
# Male      125  121

# %%
contingency_table.sum(axis=1)
# Out:
# Gender
# Female    265
# Male      246
# dtype: int64

# %%
contingency_table.sum(axis=0)
# Out:
# Purchase
# No     231
# Yes    280
# dtype: int64

# %%
contingency_table.astype("float").div(contingency_table.sum(axis=1), axis=0)
# Out:
# Purchase       No      Yes
# Gender
# Female    0.40000  0.60000
# Male      0.50813  0.49187

# %% [markdown]
# ## La Probabilidad Condicional

# %% [markdown]
#     * Cual es la probabilidad de que un cliente compre un producto sabiendo que es un hombre?
#     * Cual es la probabilidad de que sabiendo que un cliente compra un producto sea mujer?

# %%
## Numero total de compras realizadas por hombres / Cantidad de hombres
121/246
# Out:
# 0.491869918699187

# %%
## Numero de compras realizadas por mujeres / numero total de compras
159/280
# Out:
# 0.5678571428571428

# %% [markdown]
# ## Ratio de probabilidades

# %% [markdown]
# Cociente entre los casos de exito y los casos de fracaso en el suceso estudiado.

# %% [markdown]
# Probabilidad de hacer compra sabiendo que es hombre
#
# Probabilidad de hacer compra sabiendo que es mujer

# %%
pm = 121/246
pf = 159/265

odds_m = pm/(1-pm)  #121/125
odds_f = pf/(1-pf)  #159/106

# %%
odds_m #PROBABILIDAD DE FRACASO MAYOR QUE EL DE EXITO PORQUE ES MENOR A 1
# Out:
# 0.9680000000000002

# %%
odds_f   #PROBABILIDAD DE EXITO MAYOR QUE EL DE FRACASO PORQUE ES MAYOR A 1
# Out:
# 1.4999999999999998

# %%
## El valor del ratio puede ir de 0 a infinito

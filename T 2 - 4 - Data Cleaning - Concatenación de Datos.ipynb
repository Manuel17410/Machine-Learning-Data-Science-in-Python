# %% [markdown]
# ## Datos Distribuidos

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\Asus\Desktop\Datasets\datasets\distributed-data\001.csv")

# %%
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %%
data.shape
# Out:
# (1461, 4)

# %%
#Primero exportamos el primer fichero. Una vez cargado, hacemos un bucle para ir recorriendo todos y cada uno de los ficheros
#importante tener una consistencia en el nombre de los ficheros. Dentro del bucle importamos los ficheros uno a uno, cada uno
#de ellos debe apendizarse, es decir, añadirse al final del primer fichero que hemos cargado. 
#Luego finalmente repetimos el bucle hasta que no queden ficheros.

# %%
filepath = r"C:\Users\Asus\Desktop\Datasets\datasets\distributed-data"

data = pd.read_csv(r"C:\Users\Asus\Desktop\Datasets\datasets\distributed-data\001.csv")

for i in range(2,333):
    if i < 10:
        filename = "00" + str(i)
    if 10 <= i < 100:
        filename = "0" + str(i)
    if i>=100:
        filename = str(i)
    file = filepath + filename + ".csv"
    temp_data = pd.read_csv(r"file")
    
    data = pd.concat([data,temp_data], axis=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-bfb3b1f5c33f> in <module>
#      11         filename = str(i)
#      12     file = filepath + filename + ".csv"
# ---> 13     temp_data = pd.read_csv(r"file")
#      14
#      15     data = pd.concat([data,temp_data], axis=0)
#
# ...

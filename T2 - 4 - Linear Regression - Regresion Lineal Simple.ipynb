# %% [markdown]
# # Regresion Lineal Simple en Python
#
# ## El parquete statsmodel para regresion lineal

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Asus\Desktop\Datasets\datasets\ads\Advertising.csv")

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import statsmodels.formula.api as smf

# %%
lm = smf.ols(formula="Sales-TV", data=data).fit()
# Out:
# ---------------------------------------------------------------------------
# PatsyError                                Traceback (most recent call last)
# <ipython-input-6-c58b84240e2c> in <module>
# ----> 1 lm = smf.ols(formula="Sales-TV", data=data).fit()
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\base\model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     157
#     158         tmp = handle_formula_data(data, None, formula, depth=eval_env,
# --> 159                                   missing=missing)
#     160         ((endog, exog), missing_idx, design_info) = tmp
#     161
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\formula\formulatools.py in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
# ...

# %%
lm.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-150d66f543e3> in <module>
# ----> 1 lm.params
#
# NameError: name 'lm' is not defined

# %%
lm.pvalues
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-05ea24a0de35> in <module>
# ----> 1 lm.pvalues
#
# NameError: name 'lm' is not defined

# %%
lm.rsquared
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-1f495b69e67f> in <module>
# ----> 1 lm.rsquared
#
# NameError: name 'lm' is not defined

# %%
lm.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a0224a4402c9> in <module>
# ----> 1 lm.summary()
#
# NameError: name 'lm' is not defined

# %%
sales_pred = lm.predict(pd.DataFrame(data["TV"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-94118666fa6b> in <module>
# ----> 1 sales_pred = lm.predict(pd.DataFrame(data["TV"]))
#
# NameError: name 'lm' is not defined

# %%
data.plot(kind = "scatter", x = "TV", y="Sales")
plt.plot(pd.DataFrame(data["TV"]), sales_pred,c="red", linewidth=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d9e453d35aca> in <module>
# ----> 1 data.plot(kind = "scatter", x = "TV", y="Sales")
#       2 plt.plot(pd.DataFrame(data["TV"]), sales_pred,c="red", linewidth=2)
#
# NameError: name 'data' is not defined

# %%
data["Sales Pred"] = 7.06960505 + 0.0437845 * data["TV"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bb8a4280dc5b> in <module>
# ----> 1 data["Sales Pred"] = 7.06960505 + 0.0437845 * data["TV"]
#
# NameError: name 'data' is not defined

# %%
data["RSE"] = (data["Sales"] - data["Sales_Pred"])**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8b91777c1eeb> in <module>
# ----> 1 data["RSE"] = (data["Sales"] - data["Sales_Pred"])**2
#
# NameError: name 'data' is not defined

# %%
SSD = sum(data["RSE"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-534f97b5bd13> in <module>
# ----> 1 SSD = sum(data["RSE"])
#
# NameError: name 'data' is not defined

# %%
RSE = np.sqrt(SSD/(len(data)-2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-017218e1f7d0> in <module>
# ----> 1 RSE = np.sqrt(SSD/(len(data)-2))
#
# NameError: name 'np' is not defined

# %%
sales_m = np.mean(data["Sales"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3ad5678cfb86> in <module>
# ----> 1 sales_m = np.mean(data["Sales"])
#
# NameError: name 'np' is not defined

# %%
sales_m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-702eb4ff3fb3> in <module>
# ----> 1 sales_m
#
# NameError: name 'sales_m' is not defined

# %%
error = RSE/sales_m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e633d0139045> in <module>
# ----> 1 error = RSE/sales_m
#
# NameError: name 'RSE' is not defined

# %%
error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ded28046d863> in <module>
# ----> 1 error
#
# NameError: name 'error' is not defined

# %%
plt.hist(data["Sales"] - data["Sales_Pred"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-5c00a9ebaa6c> in <module>
# ----> 1 plt.hist(data["Sales"] - data["Sales_Pred"])
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Regresion Lineal Multiple

# %% [markdown]
# ### El paquete statsmodel para regresion lineal simple

# %%
## Cuanto menos es el P valor, mejor para el modelo
## Quedanos con las que aumentan el R2


##Puedo tomar dos enfoques, partir de una variable e ir agregando una a una.
## Una variable añanida al modelo resulte de un error residual menos en la suma de los
##cuadrados residuales, se quedara. Caso contrario, no se incluya. Enfoque constructivo
## o bien arrancar con todas e ir eliminando otras.Enfoque destructivo.

# %%
#Añadir el newspaper a la formula existente
lm2 = smf.ols(formula="Sales-TV + Newspaper", data=data).fit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ede3c70f8468> in <module>
#       1 #Añadir el newspaper a la formula existente
# ----> 2 lm = smf.ols(formula="Sales-TV + Newspaper", data=data).fit()
#
# NameError: name 'smf' is not defined

# %%
lm2.params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-c85ee9f93a7b> in <module>
# ----> 1 lm2.params
#
# NameError: name 'lm2' is not defined

# %%
lm2.pvalues
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c5b1a6cc7c94> in <module>
# ----> 1 lms.pvalues
#
# NameError: name 'lms' is not defined

# %%
lm2.rsquared
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f91371baaca0> in <module>
# ----> 1 lm2.rquared
#
# NameError: name 'lm2' is not defined

# %%
lms.rsquared_adj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0da227fd2328> in <module>
# ----> 1 lms.rsquared_adj
#
# NameError: name 'lms' is not defined

# %%
sales_pred = lm2.predict(data["TV","Newspaper"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-0c3eb565b586> in <module>
# ----> 1 sales_pred = lm2.predict(data["TV","Newspaper"])
#
# NameError: name 'lm2' is not defined

# %%
##Si aumento el R2, mejor para el modelo.

# %%
SSD = sum(data["Sales"]-sales_pred)**2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-928c16124218> in <module>
# ----> 1 SSD = sum(data["Sales"]-sales_pred)**2
#
# NameError: name 'data' is not defined

# %%
RSE = np.sqrt(SSD/(len(data)-3))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-8b46120aa9f4> in <module>
# ----> 1 RSE = np.sqrt(SSD/(len(data)-3))
#
# NameError: name 'np' is not defined

# %%
sales_m = np.mean(data["Sales"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-3ad5678cfb86> in <module>
# ----> 1 sales_m = np.mean(data["Sales"])
#
# NameError: name 'np' is not defined

# %%
error = RSE/sales_m
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-e633d0139045> in <module>
# ----> 1 error = RSE/sales_m
#
# NameError: name 'RSE' is not defined

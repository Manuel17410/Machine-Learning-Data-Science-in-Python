# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_ads = pd.read_csv(r"C:\Users\Asus\Desktop\Datasets\datasets\ads\Advertising.csv")

# %%
data_ads.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# El problema esta que cuando hay una correlacion significativa entre dos variables del modelo, pueden haber problemas.
# El periodico esta relacionado con la radio, dicha relacion incrementa la variabilidad del coef estimado para la variable
# predictora. Una interactuara negativamente con la otra.
#
# Una debe ser eliminada del modelo.
# Se utiliza un sistema estadistico. El metodo cuantifica la aparicion de una variabilidad de un coeficiente de una variable
# debido a la relacion entre dos variables. Si es muy alto, debe ser elimiando del modelo.

# %%
plt.matshow(data_ads.corr())

# %% [markdown]
# VIF = 1 , 0 CORRELACION ENTRE VARIABLES
#
# VIF INFERIOR A 5, HAY CORRELACION MODERADA PERO PUEDEN SER PARTE DEL MODELO
#
# VIF SUPERIOR A 5, DEBE SER ELIMINADA DEL MODELO

# %%
# Newspaper en funcion de la TV y la radio

lm_n = smf.ols(formula="Newspaper-TV+Radio", data=data).fit()
rsquared_tv = lm_n.rsquared
VIF = 1/(1-rsquared_tv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-16b812c8d204> in <module>
#       1 # Newspaper en funcion de la TV y la radio
#       2
# ----> 3 lm_n = smf.ols(formula="Newspaper-TV+Radio", data=data).fit()
#       4 rsquared_tv = lm_n.rsquared
#       5 VIF = 1/(1-rsquared_tv)
#
# NameError: name 'smf' is not defined

# %%
##Si dos variables tienen el mismo VIF, significa que estan relacionadas entre ellas.
##Como estan correlacionadas, es facil saber que VIF sera mayor
#El modelo con las 3 variables no mejora, y entre quedanos con el periodico o la radio
#conviene quedarse con la radio ya que da mejor precision.
